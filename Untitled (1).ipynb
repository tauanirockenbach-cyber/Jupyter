# %%
import os
import subprocess
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1.5

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/folders/1PDmvU5FNWNNxG7K_xrBajnlvto_iYayI")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(8) 

pyautogui.moveTo(250, 340)

pyautogui.click(button='right')
time.sleep(2) 

for _ in range(7):   
    pyautogui.press('down')
    pyautogui.press('enter')
